# %% [markdown]
# # Experiment - 1

# %% [markdown]
# Q1. To create a program to display grayscale image using read and write operation.

# %%
# import library
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# image path
img_path = '/content/pokemon.png'

# %%
# reading image BGR to RGB
img = cv2.imread(img_path, cv2.IMREAD_COLOR_RGB)
# reading image BGR to grayscale image
gray_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# %%
print(f"The shape of the RGB image: {img.shape}")
print(f"The shape of the Grayscale image: {gray_img.shape}")
# Out:
# The shape of the RGB image: (1080, 1927, 3)
# The shape of the Grayscale image: (1080, 1927)

# %%
# subplot the RGB and GRAYSCALE Image
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("RGB Image")
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(gray_img, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()

# %%
# saving grayscale image
plt.imsave('output.jpg', gray_img, cmap='gray')
# loading saved image and reading
g_img = cv2.imread('output.jpg')
# plotting the image
plt.imshow(g_img)
plt.axis('off')
plt.show()
